# %%
#load imports
import pandas as pd
import datetime as dt

# %%
#Load CSV file into df
crime_df = pd.read_csv('C:/Users/auste/Documents/crime_data_2001_present.csv')
crime_df.head()
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# 0      True  ...  12.0            61.0       08B     1165074.0    1875917.0
# 1     False  ...  29.0            25.0        06     1138875.0    1904869.0
# 2      True  ...   8.0            44.0        06           NaN          NaN
# 3     False  ...  35.0            21.0        18     1152037.0    1920384.0
# 4      True  ...  28.0            25.0       08A     1141706.0    1900086.0
#
#    Year              Updated On   Latitude  Longitude  \
# 0  2015  02/10/2018 03:50:01 PM  41.815117 -87.670000
# 1  2015  02/10/2018 03:50:01 PM  41.895080 -87.765400
# 2  2018  04/06/2019 04:04:43 PM        NaN        NaN
# 3  2015  02/10/2018 03:50:01 PM  41.937406 -87.716650
# 4  2015  02/10/2018 03:50:01 PM  41.881903 -87.755121
#
#                         Location
# 0  (41.815117282, -87.669999562)
# 1  (41.895080471, -87.765400451)
# 2                            NaN
# 3  (41.937405765, -87.716649687)
# 4  (41.881903443, -87.755121152)
#
# [5 rows x 22 columns]

# %%
#Drop data prior to 2010
sample_crime_df = crime_df[crime_df['Year'] >= 2021]
sample_crime_df.rename(columns ={'Date': 'Datetime'}, inplace=True)

sample_crime_df
# Out:
# C:\Users\auste\anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                ID Case Number                Datetime  \
# 6909918  12260346    JE102126  01/03/2021 01:23:00 PM
# 6927718  12263464    JE105797  01/03/2021 06:59:00 AM
# 6927807  12259990    JE101773  01/03/2021 12:20:00 AM
# 6931849  12260669    JE102509  01/03/2021 08:47:00 PM
# 6931854     25702    JE102438  01/03/2021 08:09:00 PM
# ...           ...         ...                     ...
# 7469636  12585522    JF104515  01/05/2022 09:25:00 PM
# 7469637  12585531    JF104558  01/05/2022 10:47:00 PM
# 7469638  12588900    JF108556  01/05/2022 09:00:00 AM
# 7469639  12585548    JF104494  01/05/2022 08:00:00 PM
# 7469640  12585195    JF104200  01/05/2022 01:00:00 PM
#
#                             Block  IUCR         Primary Type  \
# 6909918     070XX S EGGLESTON AVE  0486              BATTERY
# 6927718          080XX S YALE AVE  0820                THEFT
# 6927807   056XX W WASHINGTON BLVD  0486              BATTERY
# 6931849        057XX S RACINE AVE  2022            NARCOTICS
# 6931854  068XX S STONY ISLAND AVE  0110             HOMICIDE
# ...                           ...   ...                  ...
# 7469636      012XX S MICHIGAN AVE  0910  MOTOR VEHICLE THEFT
# 7469637        042XX S ARCHER AVE  1310      CRIMINAL DAMAGE
# 7469638         042XX W KINZIE ST  0820                THEFT
# 7469639         059XX W NORTH AVE  0486              BATTERY
# 7469640           017XX E 71ST ST  031A              ROBBERY
#
#                      Description Location Description  Arrest  Domestic  ...  \
# 6909918  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True  ...
# 6927718           $500 AND UNDER            RESIDENCE   False     False  ...
# 6927807  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True  ...
# 6931849        POSSESS - COCAINE               STREET    True     False  ...
# 6931854      FIRST DEGREE MURDER               STREET   False     False  ...
# ...                          ...                  ...     ...       ...  ...
# 7469636               AUTOMOBILE            APARTMENT   False     False  ...
# 7469637              TO PROPERTY   SMALL RETAIL STORE   False     False  ...
# 7469638           $500 AND UNDER               STREET   False     False  ...
# 7469639  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True  ...
# 7469640          ARMED - HANDGUN                ALLEY   False     False  ...
#
#          Ward  Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 6909918   6.0            68.0       08B     1174496.0    1858251.0  2021
# 6927718  17.0            44.0        06     1176011.0    1851718.0  2021
# 6927807  29.0            25.0       08B     1138722.0    1900183.0  2021
# 6931849  16.0            67.0        18     1169298.0    1866822.0  2021
# 6931854   5.0            43.0       01A     1188038.0    1860051.0  2021
# ...       ...             ...       ...           ...          ...   ...
# 7469636   3.0            33.0        07     1177419.0    1894900.0  2022
# 7469637  15.0            58.0        14     1156955.0    1876483.0  2022
# 7469638  28.0            26.0        06     1148151.0    1902249.0  2022
# 7469639  29.0            25.0       08B     1136266.0    1910020.0  2022
# 7469640   7.0            43.0        03     1189225.0    1858224.0  2022
#
#                      Updated On   Latitude  Longitude  \
# 6909918  01/16/2021 03:49:23 PM  41.766435 -87.635964
# 6927718  01/16/2021 03:49:23 PM  41.748474 -87.630607
# 6927807  01/16/2021 03:49:23 PM  41.882224 -87.766076
# 6931849  01/16/2021 03:49:23 PM  41.790069 -87.654769
# 6931854  01/10/2021 03:51:53 PM  41.771062 -87.586271
# ...                         ...        ...        ...
# 7469636  01/12/2022 03:50:56 PM  41.866938 -87.624142
# 7469637  01/12/2022 03:50:56 PM  41.816839 -87.699766
# 7469638  01/12/2022 03:50:56 PM  41.887717 -87.731399
# 7469639  01/12/2022 03:50:56 PM  41.909262 -87.774860
# 7469640  01/12/2022 03:50:56 PM  41.766021 -87.581978
#
#                               Location
# 6909918  (41.766435144, -87.635963997)
# 6927718  (41.748473982, -87.630606588)
# 6927807   (41.88222427, -87.766076162)
# 6931849   (41.79006908, -87.654768679)
# 6931854  (41.771062488, -87.586270811)
# ...                                ...
# 7469636  (41.866937617, -87.624141504)
# 7469637   (41.81683858, -87.699766152)
# 7469638  (41.887717361, -87.731399256)
# 7469639  (41.909262448, -87.774859625)
# 7469640  (41.766020673, -87.581978274)
#
# [206997 rows x 22 columns]

# %%
#Split Date column into seperate Date and time columns

sample_crime_df['Date'] = pd.to_datetime(sample_crime_df['Datetime']).dt.date
sample_crime_df['Time'] = pd.to_datetime(sample_crime_df['Datetime']).dt.time
sample_crime_df
# Out:
# C:\Users\auste\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\auste\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                ID Case Number                Datetime  \
# 6909918  12260346    JE102126  01/03/2021 01:23:00 PM
# 6927718  12263464    JE105797  01/03/2021 06:59:00 AM
# 6927807  12259990    JE101773  01/03/2021 12:20:00 AM
# 6931849  12260669    JE102509  01/03/2021 08:47:00 PM
# 6931854     25702    JE102438  01/03/2021 08:09:00 PM
# ...           ...         ...                     ...
# 7469636  12585522    JF104515  01/05/2022 09:25:00 PM
# 7469637  12585531    JF104558  01/05/2022 10:47:00 PM
# 7469638  12588900    JF108556  01/05/2022 09:00:00 AM
# 7469639  12585548    JF104494  01/05/2022 08:00:00 PM
# 7469640  12585195    JF104200  01/05/2022 01:00:00 PM
#
#                             Block  IUCR         Primary Type  \
# 6909918     070XX S EGGLESTON AVE  0486              BATTERY
# 6927718          080XX S YALE AVE  0820                THEFT
# 6927807   056XX W WASHINGTON BLVD  0486              BATTERY
# 6931849        057XX S RACINE AVE  2022            NARCOTICS
# 6931854  068XX S STONY ISLAND AVE  0110             HOMICIDE
# ...                           ...   ...                  ...
# 7469636      012XX S MICHIGAN AVE  0910  MOTOR VEHICLE THEFT
# 7469637        042XX S ARCHER AVE  1310      CRIMINAL DAMAGE
# 7469638         042XX W KINZIE ST  0820                THEFT
# 7469639         059XX W NORTH AVE  0486              BATTERY
# 7469640           017XX E 71ST ST  031A              ROBBERY
#
#                      Description Location Description  Arrest  Domestic  ...  \
# 6909918  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True  ...
# 6927718           $500 AND UNDER            RESIDENCE   False     False  ...
# 6927807  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True  ...
# 6931849        POSSESS - COCAINE               STREET    True     False  ...
# 6931854      FIRST DEGREE MURDER               STREET   False     False  ...
# ...                          ...                  ...     ...       ...  ...
# 7469636               AUTOMOBILE            APARTMENT   False     False  ...
# 7469637              TO PROPERTY   SMALL RETAIL STORE   False     False  ...
# 7469638           $500 AND UNDER               STREET   False     False  ...
# 7469639  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True  ...
# 7469640          ARMED - HANDGUN                ALLEY   False     False  ...
#
#          FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 6909918       08B     1174496.0     1858251.0  2021  01/16/2021 03:49:23 PM
# 6927718        06     1176011.0     1851718.0  2021  01/16/2021 03:49:23 PM
# 6927807       08B     1138722.0     1900183.0  2021  01/16/2021 03:49:23 PM
# 6931849        18     1169298.0     1866822.0  2021  01/16/2021 03:49:23 PM
# 6931854       01A     1188038.0     1860051.0  2021  01/10/2021 03:51:53 PM
# ...           ...           ...           ...   ...                     ...
# 7469636        07     1177419.0     1894900.0  2022  01/12/2022 03:50:56 PM
# 7469637        14     1156955.0     1876483.0  2022  01/12/2022 03:50:56 PM
# 7469638        06     1148151.0     1902249.0  2022  01/12/2022 03:50:56 PM
# 7469639       08B     1136266.0     1910020.0  2022  01/12/2022 03:50:56 PM
# 7469640        03     1189225.0     1858224.0  2022  01/12/2022 03:50:56 PM
#
#           Latitude  Longitude                       Location        Date  \
# 6909918  41.766435 -87.635964  (41.766435144, -87.635963997)  2021-01-03
# 6927718  41.748474 -87.630607  (41.748473982, -87.630606588)  2021-01-03
# 6927807  41.882224 -87.766076   (41.88222427, -87.766076162)  2021-01-03
# 6931849  41.790069 -87.654769   (41.79006908, -87.654768679)  2021-01-03
# 6931854  41.771062 -87.586271  (41.771062488, -87.586270811)  2021-01-03
# ...            ...        ...                            ...         ...
# 7469636  41.866938 -87.624142  (41.866937617, -87.624141504)  2022-01-05
# 7469637  41.816839 -87.699766   (41.81683858, -87.699766152)  2022-01-05
# 7469638  41.887717 -87.731399  (41.887717361, -87.731399256)  2022-01-05
# 7469639  41.909262 -87.774860  (41.909262448, -87.774859625)  2022-01-05
# 7469640  41.766021 -87.581978  (41.766020673, -87.581978274)  2022-01-05
#
#              Time
# 6909918  13:23:00
# 6927718  06:59:00
# 6927807  00:20:00
# 6931849  20:47:00
# 6931854  20:09:00
# ...           ...
# 7469636  21:25:00
# 7469637  22:47:00
# 7469638  09:00:00
# 7469639  20:00:00
# 7469640  13:00:00
#
# [206997 rows x 24 columns]

# %%
#drop unneeded columns
sample_crime_df = sample_crime_df.drop(columns=['Case Number', 'Datetime', 'Updated On', 'X Coordinate', 'Y Coordinate', 'Location', 'Beat'])
sample_crime_df.head()
# Out:
#                ID                     Block  IUCR Primary Type  \
# 6909918  12260346     070XX S EGGLESTON AVE  0486      BATTERY
# 6927718  12263464          080XX S YALE AVE  0820        THEFT
# 6927807  12259990   056XX W WASHINGTON BLVD  0486      BATTERY
# 6931849  12260669        057XX S RACINE AVE  2022    NARCOTICS
# 6931854     25702  068XX S STONY ISLAND AVE  0110     HOMICIDE
#
#                      Description Location Description  Arrest  Domestic  \
# 6909918  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True
# 6927718           $500 AND UNDER            RESIDENCE   False     False
# 6927807  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True
# 6931849        POSSESS - COCAINE               STREET    True     False
# 6931854      FIRST DEGREE MURDER               STREET   False     False
#
#          District  Ward  Community Area FBI Code  Year   Latitude  Longitude  \
# 6909918       7.0   6.0            68.0      08B  2021  41.766435 -87.635964
# 6927718       6.0  17.0            44.0       06  2021  41.748474 -87.630607
# 6927807      15.0  29.0            25.0      08B  2021  41.882224 -87.766076
# 6931849       7.0  16.0            67.0       18  2021  41.790069 -87.654769
# 6931854       3.0   5.0            43.0      01A  2021  41.771062 -87.586271
#
#                Date      Time
# 6909918  2021-01-03  13:23:00
# 6927718  2021-01-03  06:59:00
# 6927807  2021-01-03  00:20:00
# 6931849  2021-01-03  20:47:00
# 6931854  2021-01-03  20:09:00

# %%
sample_crime_df['Primary Type'].unique()
# Out:
# array(['BATTERY', 'THEFT', 'NARCOTICS', 'HOMICIDE', 'ASSAULT',
#        'WEAPONS VIOLATION', 'CRIMINAL DAMAGE', 'CRIMINAL TRESPASS',
#        'DECEPTIVE PRACTICE', 'ROBBERY', 'BURGLARY', 'MOTOR VEHICLE THEFT',
#        'SEX OFFENSE', 'OTHER OFFENSE', 'OFFENSE INVOLVING CHILDREN',
#        'PUBLIC PEACE VIOLATION', 'INTERFERENCE WITH PUBLIC OFFICER',
#        'STALKING', 'CRIMINAL SEXUAL ASSAULT', 'ARSON', 'PROSTITUTION',
#        'INTIMIDATION', 'KIDNAPPING', 'LIQUOR LAW VIOLATION',
#        'CONCEALED CARRY LICENSE VIOLATION', 'OBSCENITY',
#        'PUBLIC INDECENCY', 'HUMAN TRAFFICKING', 'NON-CRIMINAL',
#        'GAMBLING', 'OTHER NARCOTIC VIOLATION'], dtype=object)

# %%
#create violent crime column
violent_crimes = ['HOMICIDE', 'BATTERY', 'ASSAULT', 'CRIMINAL SEXUAL ASSAULT', 'ROBBERY']
violent = []

for row in sample_crime_df['Primary Type']:
    if row in violent_crimes:
        violent.append('VIOLENT')
    else:
        violent.append('NON-VIOLENT')
        
sample_crime_df.insert(4,'Violence Status',violent,True)
sample_crime_df.head()
# Out:
#                ID                     Block  IUCR Primary Type  \
# 6909918  12260346     070XX S EGGLESTON AVE  0486      BATTERY
# 6927718  12263464          080XX S YALE AVE  0820        THEFT
# 6927807  12259990   056XX W WASHINGTON BLVD  0486      BATTERY
# 6931849  12260669        057XX S RACINE AVE  2022    NARCOTICS
# 6931854     25702  068XX S STONY ISLAND AVE  0110     HOMICIDE
#
#         Violence Status              Description Location Description  Arrest  \
# 6909918         VIOLENT  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 6927718     NON-VIOLENT           $500 AND UNDER            RESIDENCE   False
# 6927807         VIOLENT  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 6931849     NON-VIOLENT        POSSESS - COCAINE               STREET    True
# 6931854         VIOLENT      FIRST DEGREE MURDER               STREET   False
#
#          Domestic  District  Ward  Community Area FBI Code  Year   Latitude  \
# 6909918      True       7.0   6.0            68.0      08B  2021  41.766435
# 6927718     False       6.0  17.0            44.0       06  2021  41.748474
# 6927807      True      15.0  29.0            25.0      08B  2021  41.882224
# 6931849     False       7.0  16.0            67.0       18  2021  41.790069
# 6931854     False       3.0   5.0            43.0      01A  2021  41.771062
#
#          Longitude        Date      Time
# 6909918 -87.635964  2021-01-03  13:23:00
# 6927718 -87.630607  2021-01-03  06:59:00
# 6927807 -87.766076  2021-01-03  00:20:00
# 6931849 -87.654769  2021-01-03  20:47:00
# 6931854 -87.586271  2021-01-03  20:09:00

# %%
#export to csv
output_data_file = "sample_crime_data.csv"
sample_crime_df.to_csv(output_data_file, index=False)

# %%
#connect to postgresSQL and movies_df DataFrame to SQL Database
#connect to postgresSQL and movies_df DataFrame to SQL Database
from config import db_password
from sqlalchemy import create_engine
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/chicago_crime"
engine = create_engine(db_string)
sample_crime_df.to_sql(name='crime_data', con=engine)

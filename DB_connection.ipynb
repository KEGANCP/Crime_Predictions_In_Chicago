# %%
# import the modules
import pandas as pd
from config import db_password
from sqlalchemy import create_engine

# SQLAlchemy connectable
cnx = create_engine(f'postgresql://postgres:{db_password}@127.0.0.1:5432/chicago_crime').connect()

# table named 'crime_data' will be returned as a dataframe.
df = pd.read_sql_table('crime_data', cnx)
df.head()
# Out:
#      index        ID                     Block  IUCR Primary Type  \
# 0  6909903  12260346     070XX S EGGLESTON AVE  0486      BATTERY
# 1  6927701  12263464          080XX S YALE AVE  0820        THEFT
# 2  6927790  12259990   056XX W WASHINGTON BLVD  0486      BATTERY
# 3  6931831  12260669        057XX S RACINE AVE  2022    NARCOTICS
# 4  6931836     25702  068XX S STONY ISLAND AVE  0110     HOMICIDE
#
#   Violence Status              Description Location Description  Arrest  \
# 0         VIOLENT  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 1     NON-VIOLENT           $500 AND UNDER            RESIDENCE   False
# 2         VIOLENT  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3     NON-VIOLENT        POSSESS - COCAINE               STREET    True
# 4         VIOLENT      FIRST DEGREE MURDER               STREET   False
#
#    Domestic  District  Ward  Community Area FBI Code  Year   Latitude  \
# 0      True       7.0   6.0            68.0      08B  2021  41.766435
# 1     False       6.0  17.0            44.0       06  2021  41.748474
# 2      True      15.0  29.0            25.0      08B  2021  41.882224
# 3     False       7.0  16.0            67.0       18  2021  41.790069
# 4     False       3.0   5.0            43.0      01A  2021  41.771062
#
#    Longitude       Date      Time
# 0 -87.635964 2021-01-03  13:23:00
# 1 -87.630607 2021-01-03  06:59:00
# 2 -87.766076 2021-01-03  00:20:00
# 3 -87.654769 2021-01-03  20:47:00
# 4 -87.586271 2021-01-03  20:09:00
